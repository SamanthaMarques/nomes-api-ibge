# %%
import pandas as pd
import requests

# %%
url = 'https://servicodados.ibge.gov.br/api/v2/censos/nomes/samantha'

params = {'sexo': 'F'}

response = requests.request('GET', url = url, params = params)

# %%
response.status_code
# Out:
# 200

# %%
data_json = response.json()[0]['res']

# %%
pd.DataFrame(data_json)
# Out:
#        periodo  frequencia
# 0  [1960,1970[          64
# 1  [1970,1980[         984
# 2  [1980,1990[        2495
# 3  [1990,2000[        3338
# 4  [2000,2010[        2297
